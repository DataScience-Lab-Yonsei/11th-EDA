# %% [markdown]
# Analyzing hitter data with wRC+ and BABIP

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Load data

# %%
hitter_data = pd.read_csv('../datasets/hitter_detailed_stats.csv')

# %%
hitter_data.head()
# Out:
#   name     id    birthday    연도   팀  나이   P    G   타석   타수  ...  희타  희비  \
# 0  차영화  10005  1957-06-27  1982  해태  25  SS   76  323  282  ...   5   2
# 1  차영화  10005  1957-06-27  1983  해태  26  SS   82  252  229  ...   5   3
# 2  차영화  10005  1957-06-27  1984  해태  27  SS   69  185  162  ...   6   1
# 3  차영화  10005  1957-06-27  1985  해태  28  SS  106  266  238  ...  15   0
# 4  차영화  10005  1957-06-27  1986  해태  29  SS   85  192  176  ...   6   0
#
#       타율     출루     장타    OPS   wOBA  wRC+  WAR*  WPA
# 0  0.259  0.337  0.309  0.645  0.305  82.5  1.63  NaN
# 1  0.266  0.308  0.323  0.631  0.291  81.5  1.01  NaN
# 2  0.204  0.274  0.235  0.508  0.241  43.4 -0.02  NaN
# 3  0.240  0.276  0.269  0.545  0.246  43.5 -0.00  NaN
# 4  0.199  0.242  0.222  0.464  0.220  30.8 -0.46  NaN
#
# [5 rows x 34 columns]

# %%
hitter_data.columns
# Out:
# Index(['name', 'id', 'birthday', '연도', '팀', '나이', 'P', 'G', '타석', '타수', '득점',
#        '안타', '2타', '3타', '홈런', '루타', '타점', '도루', '도실', '볼넷', '사구', '고4', '삼진',
#        '병살', '희타', '희비', '타율', '출루', '장타', 'OPS', 'wOBA', 'wRC+', 'WAR*',
#        'WPA'],
#       dtype='object')

# %% [markdown]
# # Preprocessing

# %% [markdown]
# ## Calculate K%, BB% and HR/AB

# %%
hitter_data['삼진 비율'] = (hitter_data['삼진']/hitter_data['타석']).round(3)
hitter_data['볼넷 비율'] = (hitter_data['볼넷']/hitter_data['타석']).round(3)
hitter_data['타석 당 홈런'] = (hitter_data['홈런']/hitter_data['타석']).round(4)
hitter_data.columns
# Out:
# Index(['name', 'id', 'birthday', '연도', '팀', '나이', 'P', 'G', '타석', '타수', '득점',
#        '안타', '2타', '3타', '홈런', '루타', '타점', '도루', '도실', '볼넷', '사구', '고4', '삼진',
#        '병살', '희타', '희비', '타율', '출루', '장타', 'OPS', 'wOBA', 'wRC+', 'WAR*',
#        'WPA', '삼진 비율', '볼넷 비율', '타석 당 홈런'],
#       dtype='object')

# %% [markdown]
# ## Calculate BABIP

# %%
def calc_BABIP(hit, HR, AB, K, SF ):
    numerator = hit - HR
    denominator = AB - K - HR + SF
    return(numerator/denominator)

# %%
hitter_data['BABIP'] = round(calc_BABIP(hitter_data['안타'], hitter_data['홈런'], hitter_data['타수'],
                                        hitter_data['삼진'], hitter_data['희비'] ), 3)

# %%
hitter_data.head()
# Out:
#   name     id    birthday    연도   팀  나이   P    G   타석   타수  ...     장타    OPS  \
# 0  차영화  10005  1957-06-27  1982  해태  25  SS   76  323  282  ...  0.309  0.645
# 1  차영화  10005  1957-06-27  1983  해태  26  SS   82  252  229  ...  0.323  0.631
# 2  차영화  10005  1957-06-27  1984  해태  27  SS   69  185  162  ...  0.235  0.508
# 3  차영화  10005  1957-06-27  1985  해태  28  SS  106  266  238  ...  0.269  0.545
# 4  차영화  10005  1957-06-27  1986  해태  29  SS   85  192  176  ...  0.222  0.464
#
#     wOBA  wRC+  WAR*  WPA  삼진 비율  볼넷 비율  타석 당 홈런  BABIP
# 0  0.305  82.5  1.63  NaN  0.062  0.096   0.0031  0.274
# 1  0.291  81.5  1.01  NaN  0.067  0.052   0.0040  0.280
# 2  0.241  43.4 -0.02  NaN  0.130  0.081   0.0000  0.237
# 3  0.246  43.5 -0.00  NaN  0.079  0.041   0.0000  0.263
# 4  0.220  30.8 -0.46  NaN  0.047  0.047   0.0000  0.210
#
# [5 rows x 38 columns]

# %% [markdown]
# ---
# # Analysis

# %% [markdown]
# Check Hanwha Eagles hitters

# %%
hanwha_hitter_2023 = hitter_data[(hitter_data['팀']=='한화') & (hitter_data['연도']==2023)]
hanwha_hitter_2023
# Out:
#       name     id    birthday    연도   팀  나이    P    G   타석   타수  ...     장타  \
# 114    박정현  50709  2001-07-27  2023  한화  22   SS   53  113  105  ...  0.295
# 116    강재민  50705  1997-04-03  2023  한화  26    P    1    0    0  ...    NaN
# 119    최인호  50707  2000-01-30  2023  한화  23   LF   41  148  131  ...  0.427
# 199    장지승  51706  1998-07-04  2023  한화  25  NaN    3    3    3  ...  0.000
# 268    이상혁  52704  2001-09-14  2023  한화  22   CF    7    2    2  ...  0.000
# 270    유상빈  52705  2000-05-09  2023  한화  23   DH    3    8    6  ...  0.000
# 272    박준영  52731  2003-03-02  2023  한화  20    P    1    0    0  ...    NaN
# 275    권광민  52769  1997-12-12  2023  한화  26   LF   66   81   73  ...  0.274
# 304   오그레디  53712  1992-05-17  2023  한화  31   LF   22   86   80  ...  0.163
# 305   윌리엄스  53716  1993-09-08  2023  한화  30   LF   68  273  258  ...  0.403
# 306    김서현  53754  2004-05-31  2023  한화  19    P    1    0    0  ...    NaN
# 307    문현빈  53764  2004-04-20  2023  한화  19   CF  137  481  428  ...  0.362
# 308    이민준  53795  2004-02-02  2023  한화  19   SS    4    2    1  ...  0.000
# 479    이태양  60768  1990-07-03  2023  한화  33    P    1    0    0  ...    NaN
# 934    하주석  62700  1994-02-25  2023  한화  29   SS   25   38   35  ...  0.143
# 1196   윤대경  63464  1994-04-09  2023  한화  29    P    1    0    0  ...    NaN
# 1254   장운호  63700  1994-02-20  2023  한화  29   RF    4   11    9  ...  0.222
# 1271   노수광  63704  1990-08-06  2023  한화  33   LF   30   94   77  ...  0.286
# 1468   이성곤  64266  1992-03-25  2023  한화  31   DH    8   16   14  ...  0.143
# 1880   이도윤  65703  1996-10-07  2023  한화  27   SS  106  346  309  ...  0.317
# 2029   이진영  66657  1997-07-21  2023  한화  26   RF  121  422  358  ...  0.394
# 2047   김태연  66704  1997-06-10  2023  한화  26   RF   91  280  245  ...  0.363
# 2053   박상언  66707  1997-03-03  2023  한화  26    C   86  161  145  ...  0.269
# 2058   장진혁  66706  1993-09-30  2023  한화  30   CF   68  178  162  ...  0.265
# 2066   김인환  66715  1994-01-28  2023  한화  29   1B  112  365  325  ...  0.338
# 2243   박상원  67703  1994-09-09  2023  한화  29    P    3    0    0  ...    NaN
# 2275   이재용  67993  1999-02-28  2023  한화  24    C    2    2    2  ...  0.500
# 2381   이원석  68700  1999-03-31  2023  한화  24   CF   81  138  116  ...  0.216
# 2392   정은원  68743  2000-01-17  2023  한화  23   2B  122  459  388  ...  0.268
# 2514    김건  69702  2000-02-23  2023  한화  23   DH    7   12   12  ...  0.167
# 2520   허관회  69706  1999-02-12  2023  한화  24    C   10    7    7  ...  0.000
# 2528   노시환  69737  2000-12-03  2023  한화  23   3B  131  595  514  ...  0.541
# 2531   유로결  69766  2000-05-30  2023  한화  23   RF   27   53   48  ...  0.167
# 4298   정우람  74857  1985-06-01  2023  한화  38    P    1    0    0  ...    NaN
# 4966   이명기  76849  1987-12-26  2023  한화  36   DH   14   42   40  ...  0.200
# 5321   최재훈  78288  1989-08-27  2023  한화  34    C  125  417  327  ...  0.294
# 5515   오선진  78756  1989-07-07  2023  한화  34   SS   90  199  165  ...  0.267
# 5630   채은성  79192  1990-02-06  2023  한화  33   1B  137  596  521  ...  0.428
#
#         OPS   wOBA   wRC+  WAR*   WPA  삼진 비율  볼넷 비율  타석 당 홈런  BABIP
# 114   0.513  0.234   34.6 -0.31 -1.52  0.319  0.027   0.0177  0.254
# 116     NaN    NaN    NaN  0.00  0.00    NaN    NaN      NaN    NaN
# 119   0.791  0.364  124.5  1.00  0.33  0.149  0.068   0.0135  0.343
# 199   0.000  0.000 -123.9 -0.07 -0.02  0.000  0.000   0.0000  0.000
# 268   0.000  0.000 -123.9 -0.07  0.04  0.500  0.000   0.0000  0.000
# 270   0.250  0.186    0.4 -0.08 -0.11  0.125  0.125   0.0000  0.000
# 272     NaN    NaN    NaN  0.00  0.00    NaN    NaN      NaN    NaN
# 275   0.499  0.235   36.1 -0.30 -0.84  0.296  0.074   0.0247  0.191
# 304   0.337  0.167  -10.4 -0.90 -1.42  0.465  0.058   0.0000  0.244
# 305   0.678  0.310   86.0  0.32  0.00  0.231  0.029   0.0330  0.286
# 306     NaN    NaN    NaN  0.00  0.00    NaN    NaN      NaN    NaN
# 307   0.686  0.316   90.8  1.55 -0.21  0.175  0.069   0.0104  0.317
# 308   0.500  0.364  121.2  0.02  0.03  0.000  0.500   0.0000  0.000
# 479     NaN    NaN    NaN  0.00  0.00    NaN    NaN      NaN    NaN
# 934   0.327  0.169   -9.6 -0.27 -0.36  0.263  0.053   0.0000  0.160
# 1196    NaN    NaN    NaN  0.00  0.00    NaN    NaN      NaN    NaN
# 1254  0.586  0.306   83.5  0.03 -0.20  0.182  0.182   0.0000  0.286
# 1271  0.612  0.293   75.3  0.01 -0.83  0.287  0.138   0.0000  0.327
# 1468  0.343  0.165  -12.0 -0.21 -0.04  0.188  0.062   0.0000  0.182
# 1880  0.619  0.282   68.1  0.82 -1.72  0.159  0.052   0.0029  0.304
# 2029  0.738  0.343  108.8  1.93  1.58  0.301  0.126   0.0237  0.350
# 2047  0.700  0.329   99.2  0.75  0.03  0.211  0.096   0.0143  0.323
# 2053  0.522  0.245   43.0 -0.23 -1.48  0.236  0.062   0.0062  0.259
# 2058  0.552  0.269   59.3 -0.18 -0.69  0.230  0.084   0.0000  0.295
# 2066  0.640  0.301   80.2 -0.33 -0.92  0.249  0.096   0.0192  0.287
# 2243    NaN    NaN    NaN  0.00  0.00    NaN    NaN      NaN    NaN
# 2275  1.000  0.477  202.8  0.02  0.00  0.500  0.000   0.0000  1.000
# 2381  0.534  0.276   64.2  0.04 -1.11  0.239  0.152   0.0000  0.265
# 2392  0.601  0.296   76.8  0.84 -1.30  0.159  0.135   0.0044  0.268
# 2514  0.333  0.159  -14.1 -0.14 -0.12  0.667  0.000   0.0000  0.500
# 2520  0.000  0.000 -123.9 -0.16 -0.09  0.286  0.000   0.0000  0.000
# 2528  0.929  0.418  159.3  6.93  4.25  0.198  0.124   0.0521  0.332
# 2531  0.340  0.161  -14.5 -0.55 -0.63  0.189  0.019   0.0000  0.175
# 4298    NaN    NaN    NaN  0.00  0.00    NaN    NaN      NaN    NaN
# 4966  0.414  0.203   13.9 -0.36 -0.28  0.214  0.048   0.0000  0.226
# 5321  0.686  0.338  104.7  2.80  0.28  0.115  0.134   0.0024  0.286
# 5515  0.609  0.301   79.8  0.46 -0.29  0.171  0.121   0.0000  0.286
# 5630  0.779  0.358  118.6  2.64  2.17  0.171  0.087   0.0386  0.286
#
# [38 rows x 38 columns]

# %% [markdown]
# ## wRC+ Analysis

# %% [markdown]
# Hanwha Eagles hitters with AB > 100

# %%
hanwha_hitter_2023[hanwha_hitter_2023['타석']>100]
# Out:
#       name     id    birthday    연도   팀  나이   P    G   타석   타수  ...     장타  \
# 114    박정현  50709  2001-07-27  2023  한화  22  SS   53  113  105  ...  0.295
# 119    최인호  50707  2000-01-30  2023  한화  23  LF   41  148  131  ...  0.427
# 305   윌리엄스  53716  1993-09-08  2023  한화  30  LF   68  273  258  ...  0.403
# 307    문현빈  53764  2004-04-20  2023  한화  19  CF  137  481  428  ...  0.362
# 1880   이도윤  65703  1996-10-07  2023  한화  27  SS  106  346  309  ...  0.317
# 2029   이진영  66657  1997-07-21  2023  한화  26  RF  121  422  358  ...  0.394
# 2047   김태연  66704  1997-06-10  2023  한화  26  RF   91  280  245  ...  0.363
# 2053   박상언  66707  1997-03-03  2023  한화  26   C   86  161  145  ...  0.269
# 2058   장진혁  66706  1993-09-30  2023  한화  30  CF   68  178  162  ...  0.265
# 2066   김인환  66715  1994-01-28  2023  한화  29  1B  112  365  325  ...  0.338
# 2381   이원석  68700  1999-03-31  2023  한화  24  CF   81  138  116  ...  0.216
# 2392   정은원  68743  2000-01-17  2023  한화  23  2B  122  459  388  ...  0.268
# 2528   노시환  69737  2000-12-03  2023  한화  23  3B  131  595  514  ...  0.541
# 5321   최재훈  78288  1989-08-27  2023  한화  34   C  125  417  327  ...  0.294
# 5515   오선진  78756  1989-07-07  2023  한화  34  SS   90  199  165  ...  0.267
# 5630   채은성  79192  1990-02-06  2023  한화  33  1B  137  596  521  ...  0.428
#
#         OPS   wOBA   wRC+  WAR*   WPA  삼진 비율  볼넷 비율  타석 당 홈런  BABIP
# 114   0.513  0.234   34.6 -0.31 -1.52  0.319  0.027   0.0177  0.254
# 119   0.791  0.364  124.5  1.00  0.33  0.149  0.068   0.0135  0.343
# 305   0.678  0.310   86.0  0.32  0.00  0.231  0.029   0.0330  0.286
# 307   0.686  0.316   90.8  1.55 -0.21  0.175  0.069   0.0104  0.317
# 1880  0.619  0.282   68.1  0.82 -1.72  0.159  0.052   0.0029  0.304
# 2029  0.738  0.343  108.8  1.93  1.58  0.301  0.126   0.0237  0.350
# 2047  0.700  0.329   99.2  0.75  0.03  0.211  0.096   0.0143  0.323
# 2053  0.522  0.245   43.0 -0.23 -1.48  0.236  0.062   0.0062  0.259
# 2058  0.552  0.269   59.3 -0.18 -0.69  0.230  0.084   0.0000  0.295
# 2066  0.640  0.301   80.2 -0.33 -0.92  0.249  0.096   0.0192  0.287
# 2381  0.534  0.276   64.2  0.04 -1.11  0.239  0.152   0.0000  0.265
# 2392  0.601  0.296   76.8  0.84 -1.30  0.159  0.135   0.0044  0.268
# 2528  0.929  0.418  159.3  6.93  4.25  0.198  0.124   0.0521  0.332
# 5321  0.686  0.338  104.7  2.80  0.28  0.115  0.134   0.0024  0.286
# 5515  0.609  0.301   79.8  0.46 -0.29  0.171  0.121   0.0000  0.286
# 5630  0.779  0.358  118.6  2.64  2.17  0.171  0.087   0.0386  0.286
#
# [16 rows x 38 columns]

# %% [markdown]
# hitters whose wRC+ > 100 among their AB > 100
# 리그 평균보다 공격력이 좋은 타자가 5명 밖에 없다. 심지어 200타석 이상으로 보면 4명.
# 한화의 공격력은 그만큼 처참했음을 알 수 있다.

# %%
hanwha_hitter_2023[(hanwha_hitter_2023['타석']>100) & (hanwha_hitter_2023['wRC+']>100)]
# Out:
#      name     id    birthday    연도   팀  나이   P    G   타석   타수  ...     장타  \
# 119   최인호  50707  2000-01-30  2023  한화  23  LF   41  148  131  ...  0.427
# 2029  이진영  66657  1997-07-21  2023  한화  26  RF  121  422  358  ...  0.394
# 2528  노시환  69737  2000-12-03  2023  한화  23  3B  131  595  514  ...  0.541
# 5321  최재훈  78288  1989-08-27  2023  한화  34   C  125  417  327  ...  0.294
# 5630  채은성  79192  1990-02-06  2023  한화  33  1B  137  596  521  ...  0.428
#
#         OPS   wOBA   wRC+  WAR*   WPA  삼진 비율  볼넷 비율  타석 당 홈런  BABIP
# 119   0.791  0.364  124.5  1.00  0.33  0.149  0.068   0.0135  0.343
# 2029  0.738  0.343  108.8  1.93  1.58  0.301  0.126   0.0237  0.350
# 2528  0.929  0.418  159.3  6.93  4.25  0.198  0.124   0.0521  0.332
# 5321  0.686  0.338  104.7  2.80  0.28  0.115  0.134   0.0024  0.286
# 5630  0.779  0.358  118.6  2.64  2.17  0.171  0.087   0.0386  0.286
#
# [5 rows x 38 columns]

# %% [markdown]
# The number of hitters whose wRC+ > 100 by team

# %%
team_2023 = ['KT', 'LG', '키움', '롯데', '두산', '삼성', 'KIA', '한화', 'SSG', 'NC']

# %%
hitter_2023 = hitter_data[(hitter_data['연도']==2023) & (hitter_data['wRC+']>100) & (hitter_data['타석']>100)]
num_WRC_player_list = []
for team in team_2023:
    num_WRC_player_list.append(hitter_2023[hitter_2023['팀']==team].shape[0])
num_WRC_player_list
# Out:
# [6, 7, 7, 9, 6, 5, 9, 5, 7, 6]

# %%
hitter_2023.to_csv("hitter2023.csv")

# %% [markdown]
# ## WAR Analysis
#
# The total WAR of Eagles hitters was the poorest among 10 team.

# %%
hanwha_hitter_2023[(hanwha_hitter_2023['타석']>100)][['name', 'WAR*']]
# Out:
#       name  WAR*
# 114    박정현 -0.31
# 119    최인호  1.00
# 305   윌리엄스  0.32
# 307    문현빈  1.55
# 1880   이도윤  0.82
# 2029   이진영  1.93
# 2047   김태연  0.75
# 2053   박상언 -0.23
# 2058   장진혁 -0.18
# 2066   김인환 -0.33
# 2381   이원석  0.04
# 2392   정은원  0.84
# 2528   노시환  6.93
# 5321   최재훈  2.80
# 5515   오선진  0.46
# 5630   채은성  2.64

# %%
hitter_war_sum = sum(hanwha_hitter_2023[(hanwha_hitter_2023['타석']>100)][ 'WAR*'])
print(f"Hanwha hitters' WAR in total: {hitter_war_sum}")
# Out:
# Hanwha hitters' WAR in total: 19.03

# %%
hitter_data[(hitter_data['연도']==2023) & (hitter_data['타석']>100)].groupby('팀')['WAR*'].sum().\
                                                                    sort_values(ascending=False)[:10]
# Out:
# 팀
# LG     30.08
# KIA    27.43
# NC     24.57
# SSG    23.97
# 두산     22.12
# KT     20.81
# 키움     20.63
# 롯데     19.40
# 한화     19.03
# 삼성     18.27
# Name: WAR*, dtype: float64

# %% [markdown]
# ## BABIP Analysis
# Find players whose BABIP was lower than their BABIP on average among Eagles players

# %%
hitter_data.columns
# Out:
# Index(['name', 'id', 'birthday', '연도', '팀', '나이', 'P', 'G', '타석', '타수', '득점',
#        '안타', '2타', '3타', '홈런', '루타', '타점', '도루', '도실', '볼넷', '사구', '고4', '삼진',
#        '병살', '희타', '희비', '타율', '출루', '장타', 'OPS', 'wOBA', 'wRC+', 'WAR*',
#        'WPA', '삼진 비율', '볼넷 비율', '타석 당 홈런', 'BABIP'],
#       dtype='object')

# %% [markdown]
# Extract Eagles hitters in 2023

# %%
hanwha_hitter = hitter_data[(hitter_data['name'].isin(hanwha_hitter_2023['name'])) & (hitter_data['id'].isin(hanwha_hitter_2023['id']))]

# %% [markdown]
# Calculate balls in play

# %%
hanwha_hitter_sum = hanwha_hitter.groupby(['id', 'name']).sum()[['안타','홈런','타수','삼진','희비']]
hanwha_hitter_sum.index = hanwha_hitter_sum.index.droplevel(0)
hanwha_hitter_sum
# Out:
#         안타   홈런    타수   삼진  희비
# name
# 강재민      0    0     0    0   0
# 최인호     97    6   394   99   5
# 박정현    107    6   478  141   1
# 장지승     11    1    64   24   1
# 이상혁      0    0     2    1   0
# 유상빈     15    0    52   12   1
# 박준영      0    0     0    0   0
# 권광민     27    2   144   54   2
# 오그레디    10    0    80   40   1
# 윌리엄스    63    9   258   63   3
# 김서현      0    0     0    0   0
# 문현빈    114    5   428   84   5
# 이민준      0    0     1    0   0
# 이태양      0    0     1    1   0
# 하주석    727   48  2754  727  10
# 윤대경      0    0     0    0   0
# 장운호    173    5   727  172   5
# 노수광    813   35  3021  684  20
# 이성곤    163    7   657  198   5
# 이도윤    112    2   510  109   1
# 이진영    154   20   689  263   8
# 김태연    221   15   876  230  13
# 장진혁    157    3   667  160   5
# 박상언     69    5   329   84   3
# 김인환    186   23   771  213   9
# 박상원      0    0     0    0   0
# 이재용      2    1     7    3   0
# 이원석     46    2   271   99   2
# 정은원    627   31  2410  479  15
# 김건       2    0    12    8   0
# 허관회     18    0    95   32   2
# 노시환    487   68  1851  508  13
# 유로결     15    0   108   19   2
# 정우람      0    0     1    0   0
# 이명기   1245   30  4101  619  25
# 최재훈    779   26  3023  498  19
# 오선진    629   18  2612  509  14
# 채은성   1129  119  3857  718  58

# %% [markdown]
# Calculate BABIP in total

# %%
hanwha_hitter_sum['BABIP'] = round(calc_BABIP(hanwha_hitter_sum['안타'],
                                              hanwha_hitter_sum['홈런'],
                                              hanwha_hitter_sum['타수'],
                                              hanwha_hitter_sum['삼진'],
                                              hanwha_hitter_sum['희비'] ), 3)
hanwha_hitter_sum["balls_in_play"] = hanwha_hitter_sum['타수'] \
                                    -hanwha_hitter_sum['홈런'] \
                                    -hanwha_hitter_sum['삼진'] \
                                    +hanwha_hitter_sum['희비']
hanwha_hitter_sum
# Out:
#         안타   홈런    타수   삼진  희비  BABIP  balls_in_play
# name
# 강재민      0    0     0    0   0    NaN              0
# 최인호     97    6   394   99   5  0.310            294
# 박정현    107    6   478  141   1  0.304            332
# 장지승     11    1    64   24   1  0.250             40
# 이상혁      0    0     2    1   0  0.000              1
# 유상빈     15    0    52   12   1  0.366             41
# 박준영      0    0     0    0   0    NaN              0
# 권광민     27    2   144   54   2  0.278             90
# 오그레디    10    0    80   40   1  0.244             41
# 윌리엄스    63    9   258   63   3  0.286            189
# 김서현      0    0     0    0   0    NaN              0
# 문현빈    114    5   428   84   5  0.317            344
# 이민준      0    0     1    0   0  0.000              1
# 이태양      0    0     1    1   0    NaN              0
# 하주석    727   48  2754  727  10  0.341           1989
# 윤대경      0    0     0    0   0    NaN              0
# 장운호    173    5   727  172   5  0.303            555
# 노수광    813   35  3021  684  20  0.335           2322
# 이성곤    163    7   657  198   5  0.341            457
# 이도윤    112    2   510  109   1  0.275            400
# 이진영    154   20   689  263   8  0.324            414
# 김태연    221   15   876  230  13  0.320            644
# 장진혁    157    3   667  160   5  0.303            509
# 박상언     69    5   329   84   3  0.263            243
# 김인환    186   23   771  213   9  0.300            544
# 박상원      0    0     0    0   0    NaN              0
# 이재용      2    1     7    3   0  0.333              3
# 이원석     46    2   271   99   2  0.256            172
# 정은원    627   31  2410  479  15  0.311           1915
# 김건       2    0    12    8   0  0.500              4
# 허관회     18    0    95   32   2  0.277             65
# 노시환    487   68  1851  508  13  0.325           1288
# 유로결     15    0   108   19   2  0.165             91
# 정우람      0    0     1    0   0  0.000              1
# 이명기   1245   30  4101  619  25  0.349           3477
# 최재훈    779   26  3023  498  19  0.299           2518
# 오선진    629   18  2612  509  14  0.291           2099
# 채은성   1129  119  3857  718  58  0.328           3078

# %% [markdown]
# Criterion of meaningfull AB values
# https://yagongso.com/?p=4405

# %%
hanwha_hitter_sum[hanwha_hitter_sum['balls_in_play']>820]
# Out:
#         안타   홈런    타수   삼진  희비  BABIP  balls_in_play
# name
# 하주석    727   48  2754  727  10  0.341           1989
# 노수광    813   35  3021  684  20  0.335           2322
# 정은원    627   31  2410  479  15  0.311           1915
# 노시환    487   68  1851  508  13  0.325           1288
# 이명기   1245   30  4101  619  25  0.349           3477
# 최재훈    779   26  3023  498  19  0.299           2518
# 오선진    629   18  2612  509  14  0.291           2099
# 채은성   1129  119  3857  718  58  0.328           3078

# %%
hanwha_hitter_2023_summary = hanwha_hitter_2023[['name', 'id', 'G', '타석', '안타', '홈런', '타점', '삼진 비율', '볼넷 비율',
                                                 '타석 당 홈런', 'OPS', 'wRC+', 'WAR*','BABIP']]

# %%
hanwha_hitter_2023_summary
# Out:
#       name     id    G   타석   안타  홈런   타점  삼진 비율  볼넷 비율  타석 당 홈런    OPS  \
# 114    박정현  50709   53  113   19   2    4  0.319  0.027   0.0177  0.513
# 116    강재민  50705    1    0    0   0    0    NaN    NaN      NaN    NaN
# 119    최인호  50707   41  148   39   2   11  0.149  0.068   0.0135  0.791
# 199    장지승  51706    3    3    0   0    0  0.000  0.000   0.0000  0.000
# 268    이상혁  52704    7    2    0   0    0  0.500  0.000   0.0000  0.000
# 270    유상빈  52705    3    8    0   0    0  0.125  0.125   0.0000  0.250
# 272    박준영  52731    1    0    0   0    0    NaN    NaN      NaN    NaN
# 275    권광민  52769   66   81   11   2    9  0.296  0.074   0.0247  0.499
# 304   오그레디  53712   22   86   10   0    8  0.465  0.058   0.0000  0.337
# 305   윌리엄스  53716   68  273   63   9   45  0.231  0.029   0.0330  0.678
# 306    김서현  53754    1    0    0   0    0    NaN    NaN      NaN    NaN
# 307    문현빈  53764  137  481  114   5   49  0.175  0.069   0.0104  0.686
# 308    이민준  53795    4    2    0   0    0  0.000  0.500   0.0000  0.500
# 479    이태양  60768    1    0    0   0    0    NaN    NaN      NaN    NaN
# 934    하주석  62700   25   38    4   0    2  0.263  0.053   0.0000  0.327
# 1196   윤대경  63464    1    0    0   0    0    NaN    NaN      NaN    NaN
# 1254   장운호  63700    4   11    2   0    1  0.182  0.182   0.0000  0.586
# 1271   노수광  63704   30   94   17   0    4  0.287  0.138   0.0000  0.612
# 1468   이성곤  64266    8   16    2   0    0  0.188  0.062   0.0000  0.343
# 1880   이도윤  65703  106  346   78   1   13  0.159  0.052   0.0029  0.619
# 2029   이진영  66657  121  422   89  10   50  0.301  0.126   0.0237  0.738
# 2047   김태연  66704   91  280   64   4   26  0.211  0.096   0.0143  0.700
# 2053   박상언  66707   86  161   29   1   13  0.236  0.062   0.0062  0.522
# 2058   장진혁  66706   68  178   36   0   12  0.230  0.084   0.0000  0.552
# 2066   김인환  66715  112  365   73   7   42  0.249  0.096   0.0192  0.640
# 2243   박상원  67703    3    0    0   0    0    NaN    NaN      NaN    NaN
# 2275   이재용  67993    2    2    1   0    0  0.500  0.000   0.0000  1.000
# 2381   이원석  68700   81  138   22   0    8  0.239  0.152   0.0000  0.534
# 2392   정은원  68743  122  459   86   2   30  0.159  0.135   0.0044  0.601
# 2514    김건  69702    7   12    2   0    0  0.667  0.000   0.0000  0.333
# 2520   허관회  69706   10    7    0   0    0  0.286  0.000   0.0000  0.000
# 2528   노시환  69737  131  595  153  31  101  0.198  0.124   0.0521  0.929
# 2531   유로결  69766   27   53    7   0    5  0.189  0.019   0.0000  0.340
# 4298   정우람  74857    1    0    0   0    0    NaN    NaN      NaN    NaN
# 4966   이명기  76849   14   42    7   0    5  0.214  0.048   0.0000  0.414
# 5321   최재훈  78288  125  417   81   1   33  0.115  0.134   0.0024  0.686
# 5515   오선진  78756   90  199   38   0   15  0.171  0.121   0.0000  0.609
# 5630   채은성  79192  137  596  137  23   84  0.171  0.087   0.0386  0.779
#
#        wRC+  WAR*  BABIP
# 114    34.6 -0.31  0.254
# 116     NaN  0.00    NaN
# 119   124.5  1.00  0.343
# 199  -123.9 -0.07  0.000
# 268  -123.9 -0.07  0.000
# 270     0.4 -0.08  0.000
# 272     NaN  0.00    NaN
# 275    36.1 -0.30  0.191
# 304   -10.4 -0.90  0.244
# 305    86.0  0.32  0.286
# 306     NaN  0.00    NaN
# 307    90.8  1.55  0.317
# 308   121.2  0.02  0.000
# 479     NaN  0.00    NaN
# 934    -9.6 -0.27  0.160
# 1196    NaN  0.00    NaN
# 1254   83.5  0.03  0.286
# 1271   75.3  0.01  0.327
# 1468  -12.0 -0.21  0.182
# 1880   68.1  0.82  0.304
# 2029  108.8  1.93  0.350
# 2047   99.2  0.75  0.323
# 2053   43.0 -0.23  0.259
# 2058   59.3 -0.18  0.295
# 2066   80.2 -0.33  0.287
# 2243    NaN  0.00    NaN
# 2275  202.8  0.02  1.000
# 2381   64.2  0.04  0.265
# 2392   76.8  0.84  0.268
# 2514  -14.1 -0.14  0.500
# 2520 -123.9 -0.16  0.000
# 2528  159.3  6.93  0.332
# 2531  -14.5 -0.55  0.175
# 4298    NaN  0.00    NaN
# 4966   13.9 -0.36  0.226
# 5321  104.7  2.80  0.286
# 5515   79.8  0.46  0.286
# 5630  118.6  2.64  0.286

# %%
hanwha_hitter_sum[hanwha_hitter_sum['balls_in_play']>820]
# Out:
#         안타   홈런    타수   삼진  희비  BABIP  balls_in_play
# name
# 하주석    727   48  2754  727  10  0.341           1989
# 노수광    813   35  3021  684  20  0.335           2322
# 정은원    627   31  2410  479  15  0.311           1915
# 노시환    487   68  1851  508  13  0.325           1288
# 이명기   1245   30  4101  619  25  0.349           3477
# 최재훈    779   26  3023  498  19  0.299           2518
# 오선진    629   18  2612  509  14  0.291           2099
# 채은성   1129  119  3857  718  58  0.328           3078

# %% [markdown]
# Compare the player's BABIP in total against his records in recent 3 years

# %%
for hitter_name in hanwha_hitter_sum[hanwha_hitter_sum['balls_in_play']>820].index:
    if hitter_name in hanwha_hitter_2023_summary[hanwha_hitter_2023_summary['타석']>100]['name'].to_list():
        print(f"{hitter_name} - BABIP in total: {hanwha_hitter_sum[hanwha_hitter_sum.index == hitter_name].loc[hitter_name, 'BABIP']}")
        print("record in recent 3 seasons")
        display(hitter_data[(hitter_data['name']==hitter_name)&(hitter_data['연도'].isin(range(2021, 2024)))]\
            [['name', 'id', '연도', '나이', 'G', '타석', '삼진 비율', '볼넷 비율',
            '타석 당 홈런', 'OPS', 'wRC+', 'WAR*','BABIP']].reset_index(drop = True))
        print("-"*100)
# Out:
# 정은원 - BABIP in total: 0.311
# record in recent 3 seasons
#   name     id    연도  나이    G   타석  삼진 비율  볼넷 비율  타석 당 홈런    OPS   wRC+  WAR*  \
# 0  정은원  68743  2021  21  139  608  0.173  0.173   0.0099  0.791  126.6  4.46
# 1  정은원  68743  2022  22  140  601  0.181  0.141   0.0133  0.749  118.2  3.70
# 2  정은원  68743  2023  23  122  459  0.159  0.135   0.0044  0.601   76.8  0.84
#
#    BABIP
# 0  0.346
# 1  0.335
# 2  0.268
# ----------------------------------------------------------------------------------------------------
# 노시환 - BABIP in total: 0.325
# record in recent 3 seasons
#   name     id    연도  나이    G   타석  삼진 비율  볼넷 비율  타석 당 홈런    OPS   wRC+  WAR*  \
# 0  노시환  69737  2021  21  107  458  0.234  0.159   0.0393  0.852  131.8  3.75
# 1  노시환  69737  2022  22  115  490  0.194  0.098   0.0122  0.738  112.5  2.65
# 2  노시환  69737  2023  23  131  595  0.198  0.124   0.0521  0.929  159.3  6.93
#
#    BABIP
# 0  0.328
# 1  0.344
# 2  0.332
# ----------------------------------------------------------------------------------------------------
# 최재훈 - BABIP in total: 0.299
# record in recent 3 seasons
#   name     id    연도  나이    G   타석  삼진 비율  볼넷 비율  타석 당 홈런    OPS   wRC+  WAR*  \
# 0  최재훈  78288  2021  32  116  467  0.146  0.152   0.0150  0.791  124.6  3.67
# 1  최재훈  78288  2022  33  114  437  0.149  0.101   0.0114  0.641   87.4  1.78
# 2  최재훈  78288  2023  34  125  417  0.115  0.134   0.0024  0.686  104.7  2.80
#
#    BABIP
# 0  0.317
# 1  0.257
# 2  0.286
# ----------------------------------------------------------------------------------------------------
# 오선진 - BABIP in total: 0.291
# record in recent 3 seasons
#   name     id    연도  나이    G   타석  삼진 비율  볼넷 비율  타석 당 홈런    OPS  wRC+  WAR*  \
# 0  오선진  78756  2021  32   23   46  0.174  0.065   0.0000  0.497  41.8 -0.08
# 1  오선진  78756  2022  33  100  306  0.167  0.059   0.0098  0.667  79.9  0.53
# 2  오선진  78756  2023  34   90  199  0.171  0.121   0.0000  0.609  79.8  0.46
#
#    BABIP
# 0  0.265
# 1  0.330
# 2  0.286
# ----------------------------------------------------------------------------------------------------
# 채은성 - BABIP in total: 0.328
# record in recent 3 seasons
#   name     id    연도  나이    G   타석  삼진 비율  볼넷 비율  타석 당 홈런    OPS   wRC+  WAR*  \
# 0  채은성  79192  2021  31  110  448  0.179  0.085   0.0357  0.812  128.2  2.86
# 1  채은성  79192  2022  32  126  526  0.167  0.051   0.0228  0.790  127.3  2.89
# 2  채은성  79192  2023  33  137  596  0.171  0.087   0.0386  0.779  118.6  2.64
#
#    BABIP
# 0  0.305
# 1  0.333
# 2  0.286
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# Conclusion
# 반등 가능성 있는 타자: 정은원, 최재훈, 오선진, 채은성
# 특히 채은성은 통산 BABIP과 지난 시즌 BABIP이 0.04가량 차이나므로 지난 시즌이 상당히 불운한 시즌이었다고 볼 수 있다.
